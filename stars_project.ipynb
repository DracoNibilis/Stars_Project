# %% [markdown]
# # Stars Project.

# %% [markdown]
# ![stars.jpg](attachment:stars.jpg)

# %% [markdown]
# #### In this project I will try to simulate the stars collection, other worlds we can say that I will create "my own galaxy".

# %% [markdown]
# general steps:
# - teorethical background
# - descriptions of data set
# - descriptions of variables
# - prepering data
# - creating dataset
# - fun, analysis
# - plots
# - maybe more
# - references

# %% [markdown]
# ***
# ### A theoretical background.

# %% [markdown]
# Stars are the most widely recognized astronomical object, and represent the most fundamental biulding blocks of galaxies.
#
#
# In astronomy , stars classification is classification based on their spectral characteristics.
